# %%
from sklearn.ensemble import RandomForestClassifier
import cv2 as cv
import numpy as np
import os
import matplotlib.pyplot as plt
from keras.layers import Input, Dense, Conv2D, MaxPool2D, GlobalAveragePooling2D
from keras.models import Sequential, Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf

# %% [markdown]
# ### setup our data

# %%
i = 0
train_dr = '/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Conjuctiva/Training'
valid_dr = '/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Conjuctiva/Validation'
anemia_data_dir = '/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Conjuctiva/Training/Anemic'
for item in os.listdir(anemia_data_dir) :
    i +=1
print(f"number of training data is {i}")
i = 0
non_anemia_data_dir = '/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Conjuctiva/Training/Non-Anemic'
i = 0
for item in os.listdir(non_anemia_data_dir) :
    i +=1
print(f"number of training non anemic data is {i}")
# Out:
# number of training data is 4219
# number of training non anemic data is 4037

# %%
## viz images :
from tensorflow.keras.preprocessing.image import load_img
img = "/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Finger_Nails/Training/Anemic/Anemic-FN-001_aug1.png"
img_1 = load_img(img)
img_1.size
# Out:
# (224, 224)

# %% [markdown]
# ### Load our data (using ImageDataGenerator) and  , rescale it

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0, 1]
    rotation_range=20,  # Rotate images by 20 degrees
    width_shift_range=0.2,  # Shift images horizontally by 20% of the width
    height_shift_range=0.2,  # Shift images vertically by 20% of the height
    shear_range=0.2,  # Shear intensity (shear angle in radians)
    zoom_range=0.2,  # Zoom range [1-zoom_range, 1+zoom_range]
    horizontal_flip=True,  # Flip images horizontally
    fill_mode='nearest'  # Fill mode for filling in newly created pixels
)

# %% [markdown]
# ### resize the images

# %%
train_generator = datagen.flow_from_directory(
    train_dr,  # Path to the training data directory
    target_size=(64, 64),  # Resize images to (64, 64)
    batch_size=32,
    class_mode='binary'  # Assuming binary classification (change as needed)
)
# Out:
# Found 8256 images belonging to 2 classes.

# %%
valid_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
    valid_dr,  # Path to the validation data directory
    target_size=(64, 64),  # Resize images to (64, 64)
    batch_size=32,
    class_mode='binary'  # Assuming binary classification (change as needed)
)
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### test our result

# %%
for item in train_generator : 
    print(item[1].shape)
    break
# Out:
# (32,)

# %% [markdown]
# ### build model architacteur

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Input
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Conv2D, MaxPool2D, GlobalAveragePooling2D
inputs = Input(shape=(64,64,3))

x1 = (Conv2D(32, (2,2), input_shape=(64,64,3), padding="same", activation="relu"))(inputs)
x2 = (MaxPool2D(2,2))(x1)
x3 = (Conv2D(64, (2,2), padding="same", activation="relu"))(x2)
x4 = (MaxPool2D(2,2))(x3)
x5 = (Conv2D(128, (2,2), padding="same", activation="relu"))(x4)
x6 = (MaxPool2D(2,2))(x5)

x7 = (GlobalAveragePooling2D())(x6)
x8 = (Dense(100, activation="relu"))(x7)
x9 = (Dense(1, activation="sigmoid"))(x8)
# Define input shape and number of classes
model = Model(inputs=inputs, outputs=x9)
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 64, 64, 32)     │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 32, 32, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 16, 16, 128)    │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        12,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,569 (213.16 KB)
#  Trainable params: 54,569 (213.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy() ,
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

# %%
history = model.fit(train_generator,validation_data=valid_generator, epochs=100)
# Out:
# Epoch 1/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.8833 - loss: 0.2710 - val_accuracy: 0.8350 - val_loss: 0.3686
# Epoch 2/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.8918 - loss: 0.2582 - val_accuracy: 0.8730 - val_loss: 0.3113
# Epoch 3/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.8913 - loss: 0.2585 - val_accuracy: 0.8780 - val_loss: 0.3148
# Epoch 4/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.8772 - loss: 0.2914 - val_accuracy: 0.8860 - val_loss: 0.2751
# Epoch 5/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9054 - loss: 0.2268 - val_accuracy: 0.8780 - val_loss: 0.3142
# Epoch 6/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9052 - loss: 0.2380 - val_accuracy: 0.8680 - val_loss: 0.2945
# Epoch 7/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.8985 - loss: 0.2435 - val_accuracy: 0.9030 - val_loss: 0.2359
# Epoch 8/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - accuracy: 0.9049 - loss: 0.2335 - val_accuracy: 0.9010 - val_loss: 0.2514
# Epoch 9/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.8963 - loss: 0.2383 - val_accuracy: 0.8750 - val_loss: 0.3089
# Epoch 10/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.8963 - loss: 0.2430 - val_accuracy: 0.9160 - val_loss: 0.2389
# Epoch 11/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9079 - loss: 0.2293 - val_accuracy: 0.9140 - val_loss: 0.2057
# Epoch 12/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - accuracy: 0.9150 - loss: 0.2186 - val_accuracy: 0.8890 - val_loss: 0.2654
# Epoch 13/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9099 - loss: 0.2132 - val_accuracy: 0.9200 - val_loss: 0.2064
# Epoch 14/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9136 - loss: 0.2062 - val_accuracy: 0.8820 - val_loss: 0.2860
# Epoch 15/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9095 - loss: 0.2283 - val_accuracy: 0.9090 - val_loss: 0.2268
# Epoch 16/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9105 - loss: 0.2135 - val_accuracy: 0.8950 - val_loss: 0.2338
# Epoch 17/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9114 - loss: 0.2132 - val_accuracy: 0.9270 - val_loss: 0.1849
# Epoch 18/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9212 - loss: 0.1926 - val_accuracy: 0.9160 - val_loss: 0.1949
# Epoch 19/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9101 - loss: 0.2124 - val_accuracy: 0.9060 - val_loss: 0.2114
# Epoch 20/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9174 - loss: 0.2040 - val_accuracy: 0.9170 - val_loss: 0.2018
# Epoch 21/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9258 - loss: 0.1957 - val_accuracy: 0.9250 - val_loss: 0.1832
# Epoch 22/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - accuracy: 0.9245 - loss: 0.1864 - val_accuracy: 0.8940 - val_loss: 0.2500
# Epoch 23/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9254 - loss: 0.1883 - val_accuracy: 0.9470 - val_loss: 0.1484
# Epoch 24/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9189 - loss: 0.1956 - val_accuracy: 0.9070 - val_loss: 0.2235
# Epoch 25/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9239 - loss: 0.1856 - val_accuracy: 0.8790 - val_loss: 0.2682
# Epoch 26/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9220 - loss: 0.1876 - val_accuracy: 0.9290 - val_loss: 0.1772
# Epoch 27/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9311 - loss: 0.1764 - val_accuracy: 0.9130 - val_loss: 0.2125
# Epoch 28/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9280 - loss: 0.1835 - val_accuracy: 0.9290 - val_loss: 0.2058
# Epoch 29/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9275 - loss: 0.1773 - val_accuracy: 0.9430 - val_loss: 0.1481
# Epoch 30/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - accuracy: 0.9304 - loss: 0.1788 - val_accuracy: 0.9190 - val_loss: 0.1881
# Epoch 31/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9288 - loss: 0.1747 - val_accuracy: 0.8910 - val_loss: 0.2559
# Epoch 32/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9286 - loss: 0.1794 - val_accuracy: 0.9190 - val_loss: 0.1935
# Epoch 33/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9327 - loss: 0.1767 - val_accuracy: 0.9080 - val_loss: 0.1878
# Epoch 34/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9246 - loss: 0.1798 - val_accuracy: 0.9090 - val_loss: 0.2236
# Epoch 35/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9309 - loss: 0.1775 - val_accuracy: 0.9380 - val_loss: 0.1560
# Epoch 36/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9390 - loss: 0.1607 - val_accuracy: 0.9340 - val_loss: 0.1629
# Epoch 37/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9354 - loss: 0.1609 - val_accuracy: 0.9350 - val_loss: 0.1752
# Epoch 38/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9306 - loss: 0.1644 - val_accuracy: 0.9330 - val_loss: 0.1671
# Epoch 39/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9309 - loss: 0.1682 - val_accuracy: 0.9450 - val_loss: 0.1390
# Epoch 40/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9404 - loss: 0.1596 - val_accuracy: 0.9270 - val_loss: 0.1640
# Epoch 41/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9289 - loss: 0.1738 - val_accuracy: 0.9590 - val_loss: 0.1201
# Epoch 42/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9423 - loss: 0.1512 - val_accuracy: 0.9170 - val_loss: 0.2283
# Epoch 43/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9417 - loss: 0.1593 - val_accuracy: 0.9380 - val_loss: 0.1464
# Epoch 44/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.9349 - loss: 0.1696 - val_accuracy: 0.9370 - val_loss: 0.1699
# Epoch 45/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 113ms/step - accuracy: 0.9318 - loss: 0.1696 - val_accuracy: 0.9270 - val_loss: 0.1707
# Epoch 46/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9387 - loss: 0.1534 - val_accuracy: 0.9220 - val_loss: 0.1967
# Epoch 47/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9406 - loss: 0.1519 - val_accuracy: 0.9140 - val_loss: 0.2214
# Epoch 48/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9383 - loss: 0.1625 - val_accuracy: 0.9270 - val_loss: 0.1800
# Epoch 49/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9333 - loss: 0.1614 - val_accuracy: 0.9530 - val_loss: 0.1118
# Epoch 50/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9465 - loss: 0.1334 - val_accuracy: 0.9200 - val_loss: 0.1838
# Epoch 51/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - accuracy: 0.9449 - loss: 0.1448 - val_accuracy: 0.9380 - val_loss: 0.1346
# Epoch 52/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9464 - loss: 0.1399 - val_accuracy: 0.9510 - val_loss: 0.1194
# Epoch 53/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9500 - loss: 0.1337 - val_accuracy: 0.9320 - val_loss: 0.1674
# Epoch 54/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9493 - loss: 0.1400 - val_accuracy: 0.9440 - val_loss: 0.1439
# Epoch 55/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 108ms/step - accuracy: 0.9402 - loss: 0.1461 - val_accuracy: 0.9200 - val_loss: 0.1947
# Epoch 56/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 41s 109ms/step - accuracy: 0.9518 - loss: 0.1231 - val_accuracy: 0.9430 - val_loss: 0.1442
# Epoch 57/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9488 - loss: 0.1395 - val_accuracy: 0.9470 - val_loss: 0.1458
# Epoch 58/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 40s 109ms/step - accuracy: 0.9521 - loss: 0.1393 - val_accuracy: 0.9560 - val_loss: 0.1199
# Epoch 59/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9371 - loss: 0.1574 - val_accuracy: 0.9450 - val_loss: 0.1323
# Epoch 60/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9559 - loss: 0.1241 - val_accuracy: 0.9370 - val_loss: 0.1643
# Epoch 61/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9561 - loss: 0.1168 - val_accuracy: 0.9560 - val_loss: 0.1126
# Epoch 62/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9554 - loss: 0.1186 - val_accuracy: 0.9560 - val_loss: 0.1112
# Epoch 63/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9498 - loss: 0.1319 - val_accuracy: 0.9530 - val_loss: 0.1204
# Epoch 64/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9490 - loss: 0.1295 - val_accuracy: 0.9690 - val_loss: 0.0896
# Epoch 65/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9536 - loss: 0.1199 - val_accuracy: 0.9560 - val_loss: 0.1163
# Epoch 66/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9469 - loss: 0.1370 - val_accuracy: 0.9370 - val_loss: 0.1613
# Epoch 67/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9596 - loss: 0.1104 - val_accuracy: 0.9640 - val_loss: 0.0972
# Epoch 68/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9549 - loss: 0.1253 - val_accuracy: 0.9520 - val_loss: 0.1175
# Epoch 69/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9453 - loss: 0.1323 - val_accuracy: 0.9490 - val_loss: 0.1357
# Epoch 70/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9469 - loss: 0.1397 - val_accuracy: 0.9500 - val_loss: 0.1268
# Epoch 71/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9523 - loss: 0.1193 - val_accuracy: 0.9230 - val_loss: 0.1971
# Epoch 72/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9544 - loss: 0.1141 - val_accuracy: 0.9190 - val_loss: 0.2078
# Epoch 73/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9501 - loss: 0.1276 - val_accuracy: 0.9500 - val_loss: 0.1305
# Epoch 74/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9598 - loss: 0.1081 - val_accuracy: 0.9640 - val_loss: 0.1029
# Epoch 75/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9587 - loss: 0.1136 - val_accuracy: 0.9540 - val_loss: 0.1325
# Epoch 76/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9586 - loss: 0.1074 - val_accuracy: 0.9390 - val_loss: 0.1641
# Epoch 77/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9638 - loss: 0.1045 - val_accuracy: 0.9550 - val_loss: 0.1111
# Epoch 78/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9621 - loss: 0.1036 - val_accuracy: 0.9380 - val_loss: 0.1419
# Epoch 79/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - accuracy: 0.9558 - loss: 0.1123 - val_accuracy: 0.9650 - val_loss: 0.0992
# Epoch 80/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9649 - loss: 0.0964 - val_accuracy: 0.9690 - val_loss: 0.0819
# Epoch 81/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9562 - loss: 0.1138 - val_accuracy: 0.9410 - val_loss: 0.1315
# Epoch 82/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9587 - loss: 0.1043 - val_accuracy: 0.9590 - val_loss: 0.0976
# Epoch 83/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9593 - loss: 0.1010 - val_accuracy: 0.9500 - val_loss: 0.1326
# Epoch 84/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9518 - loss: 0.1220 - val_accuracy: 0.9630 - val_loss: 0.0986
# Epoch 85/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9654 - loss: 0.0933 - val_accuracy: 0.9680 - val_loss: 0.0860
# Epoch 86/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9574 - loss: 0.1072 - val_accuracy: 0.9420 - val_loss: 0.1392
# Epoch 87/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9515 - loss: 0.1408 - val_accuracy: 0.9740 - val_loss: 0.0795
# Epoch 88/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9612 - loss: 0.1034 - val_accuracy: 0.9780 - val_loss: 0.0727
# Epoch 89/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9661 - loss: 0.0855 - val_accuracy: 0.9670 - val_loss: 0.0785
# Epoch 90/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9639 - loss: 0.0946 - val_accuracy: 0.9590 - val_loss: 0.1098
# Epoch 91/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9623 - loss: 0.0965 - val_accuracy: 0.9610 - val_loss: 0.0974
# Epoch 92/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9657 - loss: 0.0993 - val_accuracy: 0.9360 - val_loss: 0.1783
# Epoch 93/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 42s 112ms/step - accuracy: 0.9648 - loss: 0.0944 - val_accuracy: 0.9730 - val_loss: 0.0964
# Epoch 94/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.9698 - loss: 0.0812 - val_accuracy: 0.9470 - val_loss: 0.1363
# Epoch 95/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - accuracy: 0.9600 - loss: 0.1026 - val_accuracy: 0.9760 - val_loss: 0.0746
# Epoch 96/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 107ms/step - accuracy: 0.9670 - loss: 0.0895 - val_accuracy: 0.9440 - val_loss: 0.1589
# Epoch 97/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9688 - loss: 0.0930 - val_accuracy: 0.9520 - val_loss: 0.1147
# Epoch 98/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.9583 - loss: 0.1076 - val_accuracy: 0.9570 - val_loss: 0.0940
# Epoch 99/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - accuracy: 0.9701 - loss: 0.0826 - val_accuracy: 0.9640 - val_loss: 0.1114
# Epoch 100/100
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9712 - loss: 0.0845 - val_accuracy: 0.9180 - val_loss: 0.2085

# %% [markdown]
# ### save the model to use it

# %%
model.save('model_anemia.h5')

# %% [markdown]
# ### see our results

# %%
import pandas as pd
model_information = pd.DataFrame(history.history)
model_information
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 0   0.883236  0.270933         0.835  0.368605
# 1   0.891836  0.253711         0.873  0.311327
# 2   0.895107  0.252088         0.878  0.314836
# 3   0.889050  0.260458         0.886  0.275128
# 4   0.901405  0.234130         0.878  0.314204
# ..       ...       ...           ...       ...
# 95  0.964632  0.094696         0.944  0.158927
# 96  0.965480  0.099742         0.952  0.114696
# 97  0.961967  0.098744         0.957  0.093978
# 98  0.969234  0.085573         0.964  0.111395
# 99  0.961725  0.102096         0.918  0.208547
#
# [100 rows x 4 columns]

# %%
"""VISULIZE MODEL """
plt.plot(np.arange(100) , model_information['loss'] , label="loss")
plt.plot(np.arange(100) , model_information['val_loss'] , label="val_loss")
plt.title('MODEL LOSS AND VALIDATION LOSS')
plt.savefig('MOBILE_pretrained_loss.png')
plt.legend()
plt.show()

# %%
"""VISULIZE MODEL """
plt.plot(np.arange(100) , model_information['accuracy'] , label="accuracy")
plt.plot(np.arange(100) , model_information['val_accuracy'] , label="val_accuracy")
plt.title('MODEL accuracy AND val_accuracy LOSS')
plt.savefig('MOBILE_pretrained_val_accuracy.png')
plt.legend()
plt.show()

# %%
###test data
import os
test_images = []
test_data  = "/kaggle/input/clean-augmented-anemia-dataset/New_Augmented_Anemia_Dataset/Conjuctiva/Testing"
for item in os.listdir(test_data) :
      for img in os.listdir(os.path.join(test_data , item)) :
        test_images.append([os.path.join(test_data ,item , img ), item])

# %%
import random
random.shuffle(test_images)

# %%
test = test_images[0]
img = test[0]
label = test[1]

# %%
label
# Out:
# 'Non-Anemic'

# %%
class_names = train_generator.class_indices
classes = list(class_names.keys())
classes
# Out:
# ['Anemic', 'Non-Anemic']

# %% [markdown]
# ### evaluation

# %%
test_data_eval = model.evaluate(valid_generator)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9153 - loss: 0.2153

# %%
#TEST VISULIZATION
from tensorflow.keras.preprocessing import image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(64, 64))  # Assuming your model expects 64x64 images
    img = image.img_to_array(img)
    img = img /255.0
    img = np.expand_dims(img, axis=0)
    return img

# Function to predict class and visualize the image
def predict_and_visualize(image_paths):
    plt.figure(figsize=(10, 10))
    for i, img_path in enumerate(image_paths):
        img = preprocess_image(img_path[0])
        prediction = model.predict(img , verbose=0)
        
        predicted_class = classes[int(prediction.round()[0][0])]

        # Load and display the image
        plt.subplot(4, 5, i+1)
        plt.imshow(image.load_img(img_path[0]))
        plt.title(f' real: {img_path[1]} \n Predicted: {predicted_class}' , fontsize=10 )
        plt.axis('off')
    plt.savefig('result.png')
    plt.show()
    
predict_and_visualize(test_images[:14])
